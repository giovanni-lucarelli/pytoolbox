# %%
from mytoolbox import *
import mytoolbox.PyDataFrame as df

# %%
import mytoolbox
help(mytoolbox)
# Out:
# Help on package mytoolbox:
#
# NAME
#     mytoolbox - # from .interpolation import *
#
# PACKAGE CONTENTS
#     PyDataFrame
#     data_frame
#     interpolation
#     interpolation_bindings
#     testing_interpolation
#
# FILE
#     /home/giovanni/miniconda3/lib/python3.12/site-packages/mytoolbox/__init__.py

# %%
iris = df.DataFrame()

# %%
iris.read_csv('../datasets/iris.csv')

# %%
iris.to_pandas()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           NaN            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           NaN
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...
